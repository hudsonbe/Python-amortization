# %% [markdown]
# **What Is Amortization?**
#
# Amortization is an accounting technique used to periodically lower the book value of a loan or an intangible asset over a set period of time. Concerning a loan, amortization focuses on spreading out loan payments over time. When applied to an asset, amortization is similar to depreciation.
#
# How to Calculate Amortization of Loans
# The formula to calculate the monthly principal due on an amortized loan is as follows:
#
# \begin{aligned}&\text{Principal Payment} = \text{TMP} - \Big ( \text{OLB} \times \frac { \text{Interest Rate} }{ \text{12 Months} } \Big ) \\&\textbf{where:} \\&\text{TMP} = \text{Total monthly payment} \\&\text{OLB} = \text{Outstanding loan balance} \\\end{aligned}
# ​
#
# Principal Payment=TMP−(OLB×
# 12 Months
# Interest Rate
# ​
#  )
# where:
# TMP=Total monthly payment
# OLB=Outstanding loan balance
# ​

# %%
# Install numpy-financial
#The numpy-financial Python package is a collection of elementary financial functions
# !pip install numpy-financial
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy-financial in /usr/local/lib/python3.7/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from numpy-financial) (1.21.6)

# %%
# import the appropriate libraries

import pandas as pd
import datetime as dt
import numpy_financial as npf
import numpy as np
from IPython.display import display, HTML
import plotly.express as px
from tabulate import tabulate

# %%
# To round the number within the dataframe
# fmt =pd.options.display.float_format = '{:6.2f}'.format

# %%
# Get the user input
principal = int(input("Enter the loan amount: ")) #present value (pv)

loan_term = int(input("Enter the loan term (in years): "))

int_rate = float(input("Enter the interest rate: "))
# Out:
# Enter the loan amount: 20000
# Enter the loan term (in years): 4
# Enter the interest rate: 7.99

# %%
n_period = loan_term * 12 # Number of compounding periods
interest_rate = int_rate /1200 # Rate of interest (per period)

# Calculate monthly payment (pmt)   
#Formula ----> pmt(rate, nper, pv, fv=0, when='end')
monthly_payment = npf.pmt(interest_rate, n_period, -principal)
# monthly_payment

# The total payment is made up of payment against principal plus interest.
# Monthly interest ---> #ipmt(rate, per, nper, pv, fv=0, when='end')
#The 'per' variable represents the periods of the loan. Remember that financial equations start the period count at 1!
period = np.arange(n_period) + 1 
monthly_interest_paid = npf.ipmt(interest_rate, period,n_period, -principal)
monthly_interest_paid

#payment against loan principal.. monthly_payment - monthly_interest_paid
new_principal = npf.ppmt(interest_rate, period, n_period, -principal)
# print(f"PPMT{new_principal}")

#Each element of the sum of the 'ipmt' and 'ppmt' arrays should equal 'pmt'.``pmt = ppmt + ipmt``
np.allclose(monthly_interest_paid + new_principal, monthly_payment) #Returns True if the two arrays are equal within the given tolerance;
# Out:
# True

# %%
# Calculate the period lenght
final_date = (n_period)
drange = pd.date_range(start =dt.datetime.today(), periods= final_date,freq='M')
drange =pd.to_datetime(drange)
drange = drange.strftime("%b %Y")
# drange

# %%
#calculate the sum of interest paid
sum_interest = round(np.sum(monthly_interest_paid),2)
print(f"${sum_interest}")
# Out:
# $3431.9

# %%
#prepare the dataframe                         
data = pd.DataFrame({'Date': drange,
                     'Principal +': new_principal,
                     'Interest':monthly_interest_paid,
                     '= Payment':monthly_payment
                     })
data['Total Interest Paid'] = data['Interest'].cumsum() 
data['Balance'] = principal - data['Principal +'].cumsum()

#Make of a copy of the original data to display the amortization in $ format
amortization = data.copy()

# adds the $ through style formatting
formatters={'Principal +':lambda x: "$ {:,.2f}".format(x), 
            'Interest': lambda x: "$ {:,.2f}".format(x), 
            '= Payment': lambda x: "$ {:,.2f}".format(x),
            'Total Interest Paid': lambda x: "$ {:,.2f}".format(x),
            'Balance': lambda x: "$ {:,.2f}".format(x)}

# amortization =display(amortization.style.format(formatters))

# %%
#Make another copy of the original data to work with the rest of the data (optional)
results=data.copy()
results.head().style.format(formatters)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1a3b9_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Date</th>
#       <th class="col_heading level0 col1" >Principal +</th>
#       <th class="col_heading level0 col2" >Interest</th>
#       <th class="col_heading level0 col3" >= Payment</th>
#       <th class="col_heading level0 col4" >Total Interest Paid</th>
#       <th class="col_heading level0 col5" >Balance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a3b9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a3b9_row0_col0" class="data row0 col0" >Jul 2022</td>
#       <td id="T_1a3b9_row0_col1" class="data row0 col1" >$ 355.00</td>
#       <td id="T_1a3b9_row0_col2" class="data row0 col2" >$ 133.17</td>
#       <td id="T_1a3b9_row0_col3" class="data row0 col3" >$ 488.16</td>
#       <td id="T_1a3b9_row0_col4" class="data row0 col4" >$ 133.17</td>
#       <td id="T_1a3b9_row0_col5" class="data row0 col5" >$ 19,645.00</td>
#     </tr>
#     <tr>
#       <th id="T_1a3b9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1a3b9_row1_col0" class="data row1 col0" >Aug 2022</td>
#       <td id="T_1a3b9_row1_col1" class="data row1 col1" >$ 357.36</td>
#       <td id="T_1a3b9_row1_col2" class="data row1 col2" >$ 130.80</td>
#       <td id="T_1a3b9_row1_col3" class="data row1 col3" >$ 488.16</td>
#       <td id="T_1a3b9_row1_col4" class="data row1 col4" >$ 263.97</td>
#       <td id="T_1a3b9_row1_col5" class="data row1 col5" >$ 19,287.64</td>
#     </tr>
#     <tr>
#       <th id="T_1a3b9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1a3b9_row2_col0" class="data row2 col0" >Sep 2022</td>
#       <td id="T_1a3b9_row2_col1" class="data row2 col1" >$ 359.74</td>
#       <td id="T_1a3b9_row2_col2" class="data row2 col2" >$ 128.42</td>
#       <td id="T_1a3b9_row2_col3" class="data row2 col3" >$ 488.16</td>
#       <td id="T_1a3b9_row2_col4" class="data row2 col4" >$ 392.39</td>
#       <td id="T_1a3b9_row2_col5" class="data row2 col5" >$ 18,927.90</td>
#     </tr>
#     <tr>
#       <th id="T_1a3b9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1a3b9_row3_col0" class="data row3 col0" >Oct 2022</td>
#       <td id="T_1a3b9_row3_col1" class="data row3 col1" >$ 362.14</td>
#       <td id="T_1a3b9_row3_col2" class="data row3 col2" >$ 126.03</td>
#       <td id="T_1a3b9_row3_col3" class="data row3 col3" >$ 488.16</td>
#       <td id="T_1a3b9_row3_col4" class="data row3 col4" >$ 518.42</td>
#       <td id="T_1a3b9_row3_col5" class="data row3 col5" >$ 18,565.76</td>
#     </tr>
#     <tr>
#       <th id="T_1a3b9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1a3b9_row4_col0" class="data row4 col0" >Nov 2022</td>
#       <td id="T_1a3b9_row4_col1" class="data row4 col1" >$ 364.55</td>
#       <td id="T_1a3b9_row4_col2" class="data row4 col2" >$ 123.62</td>
#       <td id="T_1a3b9_row4_col3" class="data row4 col3" >$ 488.16</td>
#       <td id="T_1a3b9_row4_col4" class="data row4 col4" >$ 642.04</td>
#       <td id="T_1a3b9_row4_col5" class="data row4 col5" >$ 18,201.22</td>
#     </tr>
#   </tbody>
# </table>

# %%
# # function definition
def highlight_cols(x):
      
    # copy df to new - original data is not changed
    results = x.copy()
    
    # select all values to green color
    results.loc[:, :] = 'background-color: lavender'
    
    # overwrite values grey color
    results[['Principal +']] = 'background-color:#008F8D'
    results[['Interest']] = 'background-color:#852668' 
    results[['= Payment']] = 'background-color:#D84C2C'
    # return color df
    return results


display(results.style.format(formatters).apply(highlight_cols, axis = None))
# Out:
# <style type="text/css">
# #T_f5cb3_row0_col0, #T_f5cb3_row0_col4, #T_f5cb3_row0_col5, #T_f5cb3_row1_col0, #T_f5cb3_row1_col4, #T_f5cb3_row1_col5, #T_f5cb3_row2_col0, #T_f5cb3_row2_col4, #T_f5cb3_row2_col5, #T_f5cb3_row3_col0, #T_f5cb3_row3_col4, #T_f5cb3_row3_col5, #T_f5cb3_row4_col0, #T_f5cb3_row4_col4, #T_f5cb3_row4_col5, #T_f5cb3_row5_col0, #T_f5cb3_row5_col4, #T_f5cb3_row5_col5, #T_f5cb3_row6_col0, #T_f5cb3_row6_col4, #T_f5cb3_row6_col5, #T_f5cb3_row7_col0, #T_f5cb3_row7_col4, #T_f5cb3_row7_col5, #T_f5cb3_row8_col0, #T_f5cb3_row8_col4, #T_f5cb3_row8_col5, #T_f5cb3_row9_col0, #T_f5cb3_row9_col4, #T_f5cb3_row9_col5, #T_f5cb3_row10_col0, #T_f5cb3_row10_col4, #T_f5cb3_row10_col5, #T_f5cb3_row11_col0, #T_f5cb3_row11_col4, #T_f5cb3_row11_col5, #T_f5cb3_row12_col0, #T_f5cb3_row12_col4, #T_f5cb3_row12_col5, #T_f5cb3_row13_col0, #T_f5cb3_row13_col4, #T_f5cb3_row13_col5, #T_f5cb3_row14_col0, #T_f5cb3_row14_col4, #T_f5cb3_row14_col5, #T_f5cb3_row15_col0, #T_f5cb3_row15_col4, #T_f5cb3_row15_col5, #T_f5cb3_row16_col0, #T_f5cb3_row16_col4, #T_f5cb3_row16_col5, #T_f5cb3_row17_col0, #T_f5cb3_row17_col4, #T_f5cb3_row17_col5, #T_f5cb3_row18_col0, #T_f5cb3_row18_col4, #T_f5cb3_row18_col5, #T_f5cb3_row19_col0, #T_f5cb3_row19_col4, #T_f5cb3_row19_col5, #T_f5cb3_row20_col0, #T_f5cb3_row20_col4, #T_f5cb3_row20_col5, #T_f5cb3_row21_col0, #T_f5cb3_row21_col4, #T_f5cb3_row21_col5, #T_f5cb3_row22_col0, #T_f5cb3_row22_col4, #T_f5cb3_row22_col5, #T_f5cb3_row23_col0, #T_f5cb3_row23_col4, #T_f5cb3_row23_col5, #T_f5cb3_row24_col0, #T_f5cb3_row24_col4, #T_f5cb3_row24_col5, #T_f5cb3_row25_col0, #T_f5cb3_row25_col4, #T_f5cb3_row25_col5, #T_f5cb3_row26_col0, #T_f5cb3_row26_col4, #T_f5cb3_row26_col5, #T_f5cb3_row27_col0, #T_f5cb3_row27_col4, #T_f5cb3_row27_col5, #T_f5cb3_row28_col0, #T_f5cb3_row28_col4, #T_f5cb3_row28_col5, #T_f5cb3_row29_col0, #T_f5cb3_row29_col4, #T_f5cb3_row29_col5, #T_f5cb3_row30_col0, #T_f5cb3_row30_col4, #T_f5cb3_row30_col5, #T_f5cb3_row31_col0, #T_f5cb3_row31_col4, #T_f5cb3_row31_col5, #T_f5cb3_row32_col0, #T_f5cb3_row32_col4, #T_f5cb3_row32_col5, #T_f5cb3_row33_col0, #T_f5cb3_row33_col4, #T_f5cb3_row33_col5, #T_f5cb3_row34_col0, #T_f5cb3_row34_col4, #T_f5cb3_row34_col5, #T_f5cb3_row35_col0, #T_f5cb3_row35_col4, #T_f5cb3_row35_col5, #T_f5cb3_row36_col0, #T_f5cb3_row36_col4, #T_f5cb3_row36_col5, #T_f5cb3_row37_col0, #T_f5cb3_row37_col4, #T_f5cb3_row37_col5, #T_f5cb3_row38_col0, #T_f5cb3_row38_col4, #T_f5cb3_row38_col5, #T_f5cb3_row39_col0, #T_f5cb3_row39_col4, #T_f5cb3_row39_col5, #T_f5cb3_row40_col0, #T_f5cb3_row40_col4, #T_f5cb3_row40_col5, #T_f5cb3_row41_col0, #T_f5cb3_row41_col4, #T_f5cb3_row41_col5, #T_f5cb3_row42_col0, #T_f5cb3_row42_col4, #T_f5cb3_row42_col5, #T_f5cb3_row43_col0, #T_f5cb3_row43_col4, #T_f5cb3_row43_col5, #T_f5cb3_row44_col0, #T_f5cb3_row44_col4, #T_f5cb3_row44_col5, #T_f5cb3_row45_col0, #T_f5cb3_row45_col4, #T_f5cb3_row45_col5, #T_f5cb3_row46_col0, #T_f5cb3_row46_col4, #T_f5cb3_row46_col5, #T_f5cb3_row47_col0, #T_f5cb3_row47_col4, #T_f5cb3_row47_col5 {
#   background-color: lavender;
# }
# #T_f5cb3_row0_col1, #T_f5cb3_row1_col1, #T_f5cb3_row2_col1, #T_f5cb3_row3_col1, #T_f5cb3_row4_col1, #T_f5cb3_row5_col1, #T_f5cb3_row6_col1, #T_f5cb3_row7_col1, #T_f5cb3_row8_col1, #T_f5cb3_row9_col1, #T_f5cb3_row10_col1, #T_f5cb3_row11_col1, #T_f5cb3_row12_col1, #T_f5cb3_row13_col1, #T_f5cb3_row14_col1, #T_f5cb3_row15_col1, #T_f5cb3_row16_col1, #T_f5cb3_row17_col1, #T_f5cb3_row18_col1, #T_f5cb3_row19_col1, #T_f5cb3_row20_col1, #T_f5cb3_row21_col1, #T_f5cb3_row22_col1, #T_f5cb3_row23_col1, #T_f5cb3_row24_col1, #T_f5cb3_row25_col1, #T_f5cb3_row26_col1, #T_f5cb3_row27_col1, #T_f5cb3_row28_col1, #T_f5cb3_row29_col1, #T_f5cb3_row30_col1, #T_f5cb3_row31_col1, #T_f5cb3_row32_col1, #T_f5cb3_row33_col1, #T_f5cb3_row34_col1, #T_f5cb3_row35_col1, #T_f5cb3_row36_col1, #T_f5cb3_row37_col1, #T_f5cb3_row38_col1, #T_f5cb3_row39_col1, #T_f5cb3_row40_col1, #T_f5cb3_row41_col1, #T_f5cb3_row42_col1, #T_f5cb3_row43_col1, #T_f5cb3_row44_col1, #T_f5cb3_row45_col1, #T_f5cb3_row46_col1, #T_f5cb3_row47_col1 {
#   background-color: #008F8D;
# }
# #T_f5cb3_row0_col2, #T_f5cb3_row1_col2, #T_f5cb3_row2_col2, #T_f5cb3_row3_col2, #T_f5cb3_row4_col2, #T_f5cb3_row5_col2, #T_f5cb3_row6_col2, #T_f5cb3_row7_col2, #T_f5cb3_row8_col2, #T_f5cb3_row9_col2, #T_f5cb3_row10_col2, #T_f5cb3_row11_col2, #T_f5cb3_row12_col2, #T_f5cb3_row13_col2, #T_f5cb3_row14_col2, #T_f5cb3_row15_col2, #T_f5cb3_row16_col2, #T_f5cb3_row17_col2, #T_f5cb3_row18_col2, #T_f5cb3_row19_col2, #T_f5cb3_row20_col2, #T_f5cb3_row21_col2, #T_f5cb3_row22_col2, #T_f5cb3_row23_col2, #T_f5cb3_row24_col2, #T_f5cb3_row25_col2, #T_f5cb3_row26_col2, #T_f5cb3_row27_col2, #T_f5cb3_row28_col2, #T_f5cb3_row29_col2, #T_f5cb3_row30_col2, #T_f5cb3_row31_col2, #T_f5cb3_row32_col2, #T_f5cb3_row33_col2, #T_f5cb3_row34_col2, #T_f5cb3_row35_col2, #T_f5cb3_row36_col2, #T_f5cb3_row37_col2, #T_f5cb3_row38_col2, #T_f5cb3_row39_col2, #T_f5cb3_row40_col2, #T_f5cb3_row41_col2, #T_f5cb3_row42_col2, #T_f5cb3_row43_col2, #T_f5cb3_row44_col2, #T_f5cb3_row45_col2, #T_f5cb3_row46_col2, #T_f5cb3_row47_col2 {
#   background-color: #852668;
# }
# #T_f5cb3_row0_col3, #T_f5cb3_row1_col3, #T_f5cb3_row2_col3, #T_f5cb3_row3_col3, #T_f5cb3_row4_col3, #T_f5cb3_row5_col3, #T_f5cb3_row6_col3, #T_f5cb3_row7_col3, #T_f5cb3_row8_col3, #T_f5cb3_row9_col3, #T_f5cb3_row10_col3, #T_f5cb3_row11_col3, #T_f5cb3_row12_col3, #T_f5cb3_row13_col3, #T_f5cb3_row14_col3, #T_f5cb3_row15_col3, #T_f5cb3_row16_col3, #T_f5cb3_row17_col3, #T_f5cb3_row18_col3, #T_f5cb3_row19_col3, #T_f5cb3_row20_col3, #T_f5cb3_row21_col3, #T_f5cb3_row22_col3, #T_f5cb3_row23_col3, #T_f5cb3_row24_col3, #T_f5cb3_row25_col3, #T_f5cb3_row26_col3, #T_f5cb3_row27_col3, #T_f5cb3_row28_col3, #T_f5cb3_row29_col3, #T_f5cb3_row30_col3, #T_f5cb3_row31_col3, #T_f5cb3_row32_col3, #T_f5cb3_row33_col3, #T_f5cb3_row34_col3, #T_f5cb3_row35_col3, #T_f5cb3_row36_col3, #T_f5cb3_row37_col3, #T_f5cb3_row38_col3, #T_f5cb3_row39_col3, #T_f5cb3_row40_col3, #T_f5cb3_row41_col3, #T_f5cb3_row42_col3, #T_f5cb3_row43_col3, #T_f5cb3_row44_col3, #T_f5cb3_row45_col3, #T_f5cb3_row46_col3, #T_f5cb3_row47_col3 {
#   background-color: #D84C2C;
# }
# </style>
# <table id="T_f5cb3_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Date</th>
#       <th class="col_heading level0 col1" >Principal +</th>
#       <th class="col_heading level0 col2" >Interest</th>
#       <th class="col_heading level0 col3" >= Payment</th>
#       <th class="col_heading level0 col4" >Total Interest Paid</th>
#       <th class="col_heading level0 col5" >Balance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5cb3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f5cb3_row0_col0" class="data row0 col0" >Jul 2022</td>
#       <td id="T_f5cb3_row0_col1" class="data row0 col1" >$ 355.00</td>
#       <td id="T_f5cb3_row0_col2" class="data row0 col2" >$ 133.17</td>
#       <td id="T_f5cb3_row0_col3" class="data row0 col3" >$ 488.16</td>
#       <td id="T_f5cb3_row0_col4" class="data row0 col4" >$ 133.17</td>
#       <td id="T_f5cb3_row0_col5" class="data row0 col5" >$ 19,645.00</td>
#     </tr>
#     <tr>
#       <th id="T_f5cb3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f5cb3_row1_col0" class="data row1 col0" >Aug 2022</td>
#       <td id="T_f5cb3_row1_col1" class="data row1 col1" >$ 357.36</td>
#       <td id="T_f5cb3_row1_col2" class="data row1 col2" >$ 130.80</td>
#       <td id="T_f5cb3_row1_col3" class="data row1 col3" >$ 488.16</td>
#       <td id="T_f5cb3_row1_col4" class="data row1 col4" >$ 263.97</td>
#       <td id="T_f5cb3_row1_col5" class="data row1 col5" >$ 19,287.64</td>
#     </tr>
#     <tr>
#       <th id="T_f5cb3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f5cb3_row2_col0" class="data row2 col0" >Sep 2022</td>
#       <td id="T_f5cb3_row2_col1" class="data row2 col1" >$ 359.74</td>
#       <td id="T_f5cb3_row2_col2" class="data row2 col2" >$ 128.42</td>
#       <td id="T_f5cb3

# %%
drange =pd.to_datetime(drange)
date_in_year =drange.strftime("%Y")
results['Years'] = date_in_year
results['Years'] 
a =results[['Years','Principal +','Interest','Balance']]
a.groupby(['Years']).sum()
print(tabulate(a.groupby(['Years']).sum(), headers=a, tablefmt='fancy_grid'))
# Out:
# ╒═════════╤═══════════════╤════════════╤═══════════╕
# │   Years │   Principal + │   Interest │   Balance │
# ╞═════════╪═══════════════╪════════════╪═══════════╡
# │    2022 │       2165.76 │   763.228  │  112462   │
# ├─────────┼───────────────┼────────────┼───────────┤
# │    2023 │       4599.02 │  1258.96   │  184481   │
# ├─────────┼───────────────┼────────────┼───────────┤
# │    2024 │       4980.24 │   877.736  │  126845   │
# ├─────────┼───────────────┼────────────┼───────────┤
# │    2025 │       5393.06 │   464.914  │   64431.4 │
# ├─────────┼───────────────┼────────────┼───────────┤
# │    2026 │       2861.92 │    67.0636 │    7210.2 │
# ╘═════════╧═══════════════╧════════════╧═══════════╛

# %%
import plotly.graph_objects as go

colors = ['#008F8D',] *3
colors[1] = '#852668'
colors[2] = '#D84C2C'
x=['Principal', 'Interest', 'Total Paid']

y=round(results[['Principal +','Interest','= Payment']].sum(),2)
fig = go.Figure(data=[go.Bar(
     x=x, y=y,text=y, textposition='auto',
    marker_color=colors, # marker color can be a single color value or an iterable
    width=[0.5, 0.5, 1.0]
)])
# fig.update_layout(title_text='Least Used Feature')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="da888765-c12b-494b-92d2-f88e4e07612b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da888765-c12b-494b-92d2-f88e4e07612b")) {                    Plotly.newPlot(                        "da888765-c12b-494b-92d2-f88e4e07612b",                        [{"marker":{"color":["#008F8D","#852668","#D84C2C"]},"text":[20000.0,3431.9,23431.9],"textposition":"auto","width":[0.5,0.5,1.0],"x":["Principal","Interest","Total Paid"],"y":[20000.0,3431.9,23431.9],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{ ...

# %%
import plotly.graph_objects as go

# years = [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#          2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012]
fig = go.Figure()
# fig.add_trace(go.Bar(x=results['Years'] ,
#                 y=results['= Payment'],
#                 name='Principal',
#                 marker_color='#D84C2C'
#                 ))
fig.add_trace(go.Bar(x=results['Years'] ,
                y=results['Total Interest Paid'],
                name='Compound Interest',
                marker_color='#852668'
                ))

fig.update_layout(
    title='Payment VS Interest',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='Compound Interest',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8c4c3803-d366-4deb-8f86-7cd533a55c18" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c4c3803-d366-4deb-8f86-7cd533a55c18")) {                    Plotly.newPlot(                        "8c4c3803-d366-4deb-8f86-7cd533a55c18",                        [{"marker":{"color":"#852668"},"name":"Compound Interest","x":["2022","2022","2022","2022","2022","2022","2023","2023","2023","2023","2023","2023","2023","2023","2023","2023","2023","2023","2024","2024","2024","2024","2024","2024","2024","2024","2024","2024","2024","2024","2025","2025","2025","2025","2025","2025","2025","2025","2025","2025","2025","2025","2026","2026","2026","2026","2026","2026"],"y":[133.16666666666669,263.96963894820504,392.39317857950084,518.4214425048244,642.0384821801003,763.2282428705303,881.9745629435401,998.2611731570189,1112.0716959428187,1223.3896446854833,1332.1984229961756,1438.4813239817695,1542.2215295090753,1643.4021094641664,1742.0060210067747,1838.0161078197204,1931.415099353345,2022.1856100649138,2110.3101386529534,2195.771067286491,2278.550660829163,2358.631066058156,2435.9943108779485,2510.6223035288153,2582.4968317900652,2651.599562177971,2717.9120391383594,2781.415684233825,2842.091795325534,2899.921545749578,2954.885983487845,3006.9660303333685,3056.142481050121,3102.3960025272127,3145.7071329274554,3186.0562808302625,3223.4237243688385,3257.789610361625,3289.1339534379626,3317.4366351579333,3342.677403126339,3364.8358701007837,3383.8915130938162,3399.8236724690933,3412.6115510315267,3422.2342131113714,3428.670583642214,3431.8994472328236],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111," ...
